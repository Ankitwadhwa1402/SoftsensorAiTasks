# %%
from skimage import io
import matplotlib.pyplot as plt

# %%
path='test.jpg'
img=io.imread(path,as_gray=True)

# %%
print(img.shape)
img
# Out:
# (2650, 2790)
# array([[43, 42, 40, ...,  4,  2,  0],
#        [43, 42, 40, ...,  3,  1,  0],
#        [43, 42, 40, ...,  3,  1,  0],
#        ...,
#        [52, 51, 50, ..., 73, 60, 56],
#        [52, 52, 51, ..., 73, 61, 57],
#        [52, 52, 51, ..., 73, 61, 57]], dtype=uint8)

# %%
#rescale and resize

from skimage.transform import rescale,resize,downscale_local_mean

rescaled_img=rescale(img,1.0/4.0,anti_aliasing=True)

# %%
print(rescaled_img.shape)
rescaled_img
# Out:
# (662, 698)
# array([[0.15821307, 0.11902075, 0.08974296, ..., 0.03751197, 0.03430204,
#         0.01229297],
#        [0.17892942, 0.13915683, 0.10484676, ..., 0.09381115, 0.07359659,
#         0.02600277],
#        [0.20253723, 0.16232083, 0.11808755, ..., 0.18915649, 0.17236805,
#         0.10102865],
#        ...,
#        [0.17786192, 0.16354302, 0.16329392, ..., 0.33994441, 0.34366932,
#         0.26429954],
#        [0.18873793, 0.17932372, 0.17724163, ..., 0.34515127, 0.3527252 ,
#         0.2708896 ],
#        [0.19783972, 0.18600595, 0.18440925, ..., 0.35003362, 0.36261246,
#         0.27893692]])

# %%
resized_img=resize(img,(200,200))

# %%
print(resized_img.shape)
resized_img
# Out:
# (200, 200)
# array([[0.13104329, 0.03698208, 0.00217794, ..., 0.13031383, 0.12719266,
#         0.10619274],
#        [0.17885771, 0.07380081, 0.01388154, ..., 0.23434841, 0.23955869,
#         0.22755271],
#        [0.22094684, 0.1162688 , 0.04551256, ..., 0.32583339, 0.31628395,
#         0.28615084],
#        ...,
#        [0.12069683, 0.11679697, 0.13504829, ..., 0.32265769, 0.30734251,
#         0.29452219],
#        [0.14174286, 0.13973433, 0.16274094, ..., 0.33538089, 0.31868036,
#         0.30604494],
#        [0.17270901, 0.16959701, 0.1953605 , ..., 0.35927045, 0.33969085,
#         0.32527692]])

# %%
downscaled_img=downscale_local_mean(img,(4,3))
print(downscaled_img.shape)
downscaled_img
# Out:
# (663, 930)
# array([[41.91666667, 33.66666667, 27.        , ...,  9.25      ,
#          6.91666667,  2.        ],
#        [47.41666667, 39.16666667, 31.83333333, ..., 21.08333333,
#         14.16666667,  3.16666667],
#        [53.33333333, 46.08333333, 37.25      , ..., 49.5       ,
#         39.41666667, 21.58333333],
#        ...,
#        [47.58333333, 44.58333333, 44.41666667, ..., 89.        ,
#         88.33333333, 60.08333333],
#        [50.33333333, 47.41666667, 47.08333333, ..., 90.33333333,
#         92.5       , 62.41666667],
#        [25.83333333, 24.16666667, 23.33333333, ..., 46.33333333,
#         46.66666667, 31.83333333]])

# %%
plt.imshow(downscaled_img)

# %% [markdown]
# # Edge Detection

# %%
from skimage.filters import roberts,sobel,scharr,prewitt

# %%
edge_roberts=roberts(img)
plt.imshow(edge_roberts,cmap='gray')

# %%
edge_sobel=sobel(img)
edge_scharr=scharr(img)
edge_prewitt=prewitt(img)

# %%
plt.imshow(edge_sobel,cmap='gray')

# %%
plt.imshow(edge_scharr,cmap='gray')

# %%
fig,axes=plt.subplots(nrows=2,ncols=2,sharex=True,sharey=True,figsize=(8,8))
ax=axes.ravel() #flattened the array

ax[0].imshow(img,cmap=plt.cm.gray)
ax[0].set_title("Original Image")

ax[1].imshow(edge_roberts, cmap=plt.cm.gray)
ax[1].set_title("edge_roberts")

ax[2].imshow(edge_scharr ,cmap=plt.cm.gray)
ax[2].set_title("edge_scharr")

ax[3].imshow(edge_sobel, cmap=plt.cm.gray)
ax[3].set_title("edge_sobel")
for a in ax:
    a.axis("off")
plt.tight_layout()
plt.show()

# %%
from skimage.feature import canny
edge_canny=canny(img, sigma=1)     #output is binary image ,increasing sigma reduces amount of edges
plt.imshow(edge_canny)

# %% [markdown]
# # Deconvolution

# %%
import numpy as np
    
psf=np.ones((2,2))/4  # / by 9 be matrix is of 9 1's and we don't want to increase the energy of img we want to * by 1 :. / 9;

# %%
import scipy.stats as st
def gkern(kernlen=21, nsig=2):
    lim=kernlen//2+(kernlen%2)/2
    x = np.linspace(-lim, lim, kernlen+1)
    kern1d = np.diff(st.norm.cdf(x))
    kern2d = np.outer(kern1d, kern1d)
    return kern2d/kern2d.sum()
psf_gkern=gkern(5,3)
print(psf_gkern)
# Out:
# [[0.003765   0.015019   0.02379159 0.015019   0.003765  ]
#  [0.015019   0.05991246 0.0949073  0.05991246 0.015019  ]
#  [0.02379159 0.0949073  0.15034262 0.0949073  0.02379159]
#  [0.015019   0.05991246 0.0949073  0.05991246 0.015019  ]
#  [0.003765   0.015019   0.02379159 0.015019   0.003765  ]]

# %%
#sharpening the img
from skimage import restoration
deconv_img,_=restoration.unsupervised_wiener(img,psf_gkern) #psf is the value if we know why our image is blur in mathematical way 
# _ point spread function

# %%
# plt.imsave("deconv_img.jpg",deconv_img)

# %%
plt.imshow(deconv_img,cmap='gray')
