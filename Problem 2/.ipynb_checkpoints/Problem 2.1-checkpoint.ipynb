# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'C:\Users\dell\Downloads\public_150k_plus_220703.csv')
dataset.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate  ...             BusinessType  \
# 0           NaN  29150-9662     12/18/2020  ...              Corporation
# 1           NaN  29420-9000     09/28/2021  ...      Sole Proprietorship
# 2           NaN  98112-2922     03/17/2021  ...  Non-Profit Organization
# 3           NaN  92407-1740     10/16/2021  ...              Corporation
# 4           NaN         NaN     08/17/2021  ...                      NaN
#
#    OriginatingLenderLocationID                      OriginatingLender  \
# 0                        19248                           Synovus Bank
# 1                        19248                           Synovus Bank
# 2                         9551  Bank of America, National Association
# 3                         9551  Bank of America, National Association
# 4                        57328           The Huntington National Bank
#
#    OriginatingLenderCity  OriginatingLenderState      Gender      Veteran  \
# 0               COLUMBUS                      GA  Unanswered   Unanswered
# 1               COLUMBUS                      GA  Male Owned  Non-Veteran
# 2              CHARLOTTE                      NC  Unanswered   Unanswered
# 3              CHARLOTTE                      NC  Male Owned  Non-Veteran
# 4               COLUMBUS                      OH  Unanswered   Unanswered
#
#    NonProfit ForgivenessAmount ForgivenessDate
# 0        NaN         773553.37      11/20/2020
# 1        NaN         746336.24      08/12/2021
# 2          Y         696677.49      02/10/2021
# 3        NaN         395264.11      09/10/2021
# 4        NaN         370819.35      04/08/2021
#
# [5 rows x 53 columns]

# %%
df=dataset.sample(frac=1).head(1000)

# %% [markdown]
# LOAN_AMOUNT

# %%
df.columns
# Out:
# Index(['LoanNumber', 'DateApproved', 'SBAOfficeCode', 'ProcessingMethod',
#        'BorrowerName', 'BorrowerAddress', 'BorrowerCity', 'BorrowerState',
#        'BorrowerZip', 'LoanStatusDate', 'LoanStatus', 'Term',
#        'SBAGuarantyPercentage', 'InitialApprovalAmount',
#        'CurrentApprovalAmount', 'UndisbursedAmount', 'FranchiseName',
#        'ServicingLenderLocationID', 'ServicingLenderName',
#        'ServicingLenderAddress', 'ServicingLenderCity', 'ServicingLenderState',
#        'ServicingLenderZip', 'RuralUrbanIndicator', 'HubzoneIndicator',
#        'LMIIndicator', 'BusinessAgeDescription', 'ProjectCity',
#        'ProjectCountyName', 'ProjectState', 'ProjectZip', 'CD', 'JobsReported',
#        'NAICSCode', 'Race', 'Ethnicity', 'UTILITIES_PROCEED',
#        'PAYROLL_PROCEED', 'MORTGAGE_INTEREST_PROCEED', 'RENT_PROCEED',
#        'REFINANCE_EIDL_PROCEED', 'HEALTH_CARE_PROCEED',
#        'DEBT_INTEREST_PROCEED', 'BusinessType', 'OriginatingLenderLocationID',
#        'OriginatingLender', 'OriginatingLenderCity', 'OriginatingLenderState',
#        'Gender', 'Veteran', 'NonProfit', 'ForgivenessAmount',
#        'ForgivenessDate'],
#       dtype='object')

# %% [markdown]
# # Average loan for a particular State.

# %%
tempDf=df[['CurrentApprovalAmount','BorrowerState']]
tempDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 71049 to 195896
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CurrentApprovalAmount  1000 non-null   float64
#  1   BorrowerState          1000 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 23.4+ KB

# %%
tempDf=tempDf.dropna()

# %%
tempDf.groupby('BorrowerState').mean()
# Out:
#                CurrentApprovalAmount
# BorrowerState
# AK                      2.574335e+05
# AL                      6.227629e+05
# AR                      8.569930e+05
# AZ                      9.706289e+05
# CA                      4.406129e+05
# CO                      4.145361e+05
# CT                      4.316350e+05
# DC                      1.666756e+06
# DE                      2.415695e+05
# FL                      4.123341e+05
# GA                      4.022153e+05
# HI                      6.854723e+05
# IA                      5.523461e+05
# ID                      3.805120e+05
# IL                      5.790169e+05
# IN                      4.927357e+05
# KS                      3.967829e+05
# KY                      5.044474e+05
# LA                      6.554264e+05
# MA                      3.538956e+05
# MD                      2.476359e+05
# ME                      4.870470e+05
# MI                      4.021661e+05
# MN                      4.203630e+05
# MO                      5.921358e+05
# MS                      2.371280e+05
# MT                      7.147617e+05
# NC                      4.368297e+05
# ND                      2.847000e+05
# NE                      4.491207e+05
# NH                      6.776354e+05
# NJ                      7.480685e+05
# NM                      6.078333e+05
# NV                      3.091478e+05
# NY                      5.595389e+05
# OH                      5.141258e+05
# OK                      4.467335e+05
# OR                      5.915120e+05
# PA                      4.632484e+05
# PR                      4.947050e+05
# RI                      4.007175e+05
# SC                      6.813079e+05
# SD                      5.848755e+05
# TN                      4.289581e+05
# TX                      4.691346e+05
# UT                      4.151605e+05
# VA                      5.273505e+05
# VT                      2.222210e+05
# WA                      4.360905e+05
# WI                      7.656787e+05
# WV                      6.006188e+05
# WY                      2.681110e+06

# %%
tempDf = tempDf.astype({"BorrowerState": str, "CurrentApprovalAmount": int})

# %%
plt.figure(figsize=(18,4), dpi=80)
plt.bar(tempDf['BorrowerState'],tempDf['CurrentApprovalAmount'],color='cyan')
plt.title('Bar PLOT')
plt.xlabel('BorrowerState')
plt.ylabel('CurrentApprovalAmount')
plt.show()

# %%
tempDf=df[['CurrentApprovalAmount','BusinessType','Race','Gender']]
tempDf.nunique()
# Out:
# CurrentApprovalAmount    967
# BusinessType              12
# Race                       6
# Gender                     3
# dtype: int64

# %%
tempDf.shape
# Out:
# (1000, 4)

# %%
tempDf.groupby(['Race',"Gender","BusinessType"]).sum()
# Out:
#                                                                                         CurrentApprovalAmount
# Race                                      Gender       BusinessType
# American Indian or Alaska Native          Female Owned Limited  Liability Company(LLC)           2.022000e+05
#                                           Male Owned   Limited  Liability Company(LLC)           4.724610e+05
#                                                        Sole Proprietorship                       2.046950e+05
#                                                        Subchapter S Corporation                  1.550000e+05
# Asian                                     Female Owned Corporation                               6.958150e+05
#                                                        Limited  Liability Company(LLC)           2.650410e+06
#                                           Male Owned   Corporation                               7.463034e+06
#                                                        Limited  Liability Company(LLC)           2.015021e+06
#                                                        Subchapter S Corporation                  1.626000e+05
#                                           Unanswered   Corporation                               1.791661e+05
#                                                        Limited  Liability Company(LLC)           1.081100e+06
#                                                        Subchapter S Corporation                  2.307750e+05
# Black or African American                 Female Owned Limited  Liability Company(LLC)           8.612759e+05
#                                           Male Owned   501(c)6 – Non Profit Membership           4.330390e+05
#                                                        Corporation                               1.767830e+05
#                                                        Limited  Liability Company(LLC)           4.188030e+05
#                                           Unanswered   Corporation                               1.739810e+05
# Native Hawaiian or Other Pacific Islander Female Owned Corporation                               2.932650e+05
#                                           Male Owned   Limited  Liability Company(LLC)           4.383000e+05
# Unanswered                                Female Owned Corporation                               5.105415e+06
#                                                        Limited  Liability Company(LLC)           9.153308e+06
#                                                        Partnership                               1.617000e+05
#                                                        Subchapter S Corporation                  5.462133e+06
#                                           Male Owned   Corporation                               3.141001e+07
#                                                        Limited  Liability Company(LLC)           1.872562e+07
#                                                        Limited Liability Partnership             9.108795e+05
#                                                        Non-Profit Organization                   2.826727e+06
#                                                        Partnership                               1.519594e+06
#                                                        Professional Association                  2.752842e+06
#                                                        Sole Proprietorship                       5.635700e+06
#                                                        Subchapter S Corporation                  1.736820e+07
#                                           Unanswered   501(c)3 – Non Profit                      2.567135e+06
#                                                        501(c)6 – Non Profit Membership           1.198400e+06
#                                                        Cooperative                               1.779000e+05
#                                                        Corporation                               1.093448e+08
#                                                        Limited  Liability Company(LLC)           7.148287e+07
#                                                        Limited Liability Partnership             3.277370e+06
#                                                        Non-Profit Organization                   3.668519e+07
#                                                        Partnership                               9.516754e+06
#                                                        Professional Association                  9.836785e+05
#                                                        Sole Proprietorship                       1.791659e+06
#                                                        Subchapter S Corporation                  6.672812e+07
#                                                        Trust                                     1.871130e+05
# White                                     Female Owned Corporation                               6.526017e+06
#                                                        Limited  Liability Company(LLC)           1.888376e+06
#                                                        Non-Profit Organization                   2.975818e+06
#                                                        Partnership                               1.676000e+05
#                                                        Subchapter S Corporation                  4.548460e+05
#                                           Male Owned   Cooperative                               1.645170e+05
#                                                        Corporation                               2.430242e+07
#                                                        Limited  Liability Company(LLC)           1.687315e+07
#                                                        Limited Liability Partnership             4.394980e+05
#                                                        Non-Profit Organization                   1.467269e+06
#                                                        Professional Association                  3.847400e+05
#                                                        Subchapter S Corporation                  1.796237e+07
#                                           Unanswered   Corporation                               2.283475e+06
#                                                        Limited  Liability Company(LLC)           7.403940e+05
#                                                        Limited Liability Partnership             5.120000e+05
#                                                        Subchapter S Corporation                  5.924580e+05

# %% [markdown]
# # Number of jobs reported by different business types.

# %%
tempDf=df[['JobsReported','BusinessType']]
tempDf=tempDf.groupby('BusinessType').sum()
tempDf
# Out:
#                                  JobsReported
# BusinessType
# 501(c)3 – Non Profit                    199.0
# 501(c)6 – Non Profit Membership          79.0
# Cooperative                              32.0
# Corporation                           17726.0
# Limited  Liability Company(LLC)       13511.0
# Limited Liability Partnership           523.0
# Non-Profit Organization                4545.0
# Partnership                             984.0
# Professional Association                440.0
# Sole Proprietorship                     640.0
# Subchapter S Corporation              10317.0
# Trust                                    15.0

# %%
tempDf.nunique()
# Out:
# JobsReported    12
# dtype: int64

# %%
tempDf.shape
# Out:
# (12, 1)

# %%
tempDf=tempDf.dropna()

# %%
tempDf.shape
# Out:
# (12, 1)

# %%
plt.figure(figsize=(8,8), dpi=80)
plt.pie(tempDf['JobsReported'],startangle=90)
plt.legend( labels=tempDf.index, bbox_to_anchor=(-0.2, 1.),
           fontsize=16)
plt.show()

# %% [markdown]
# # Highest loan lender in each city.

# %%
tempDf=df[['BorrowerState','ServicingLenderName','CurrentApprovalAmount']].groupby('BorrowerState').max()

# %%
tempDf.sort_values('CurrentApprovalAmount',ascending=False,inplace=True)

# %%
import seaborn as sn

# %%
sns.set(rc={"figure.figsize":(17, 7)}) 
sns.barplot(x='ServicingLenderName',y='CurrentApprovalAmount',data=tempDf.head(5))
# Out:
# <AxesSubplot:xlabel='ServicingLenderName', ylabel='CurrentApprovalAmount'>
